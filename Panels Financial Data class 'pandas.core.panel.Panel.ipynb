# %%
import pandas as pd
from pandas_datareader import data

# %%
companies = ['AMZN','CVX','DB','FB','CAT']
p = data.DataReader(name = companies, data_source  = 'yahoo', start = '2016-01-01', end = '2017-12-30')
type(p)
# Out:
# pandas.core.panel.Panel

# %%
p
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 6 (items) x 504 (major_axis) x 5 (minor_axis)
# Items axis: Adj Close to Volume
# Major_axis axis: 2017-12-29 00:00:00 to 2015-12-31 00:00:00
# Minor_axis axis: AMZN to FB

# %%
p.items
# Out:
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
p.major_axis
# Out:
# DatetimeIndex(['2017-12-29', '2017-12-28', '2017-12-27', '2017-12-26',
#                '2017-12-22', '2017-12-21', '2017-12-20', '2017-12-19',
#                '2017-12-18', '2017-12-15',
#                ...
#                '2016-01-14', '2016-01-13', '2016-01-12', '2016-01-11',
#                '2016-01-08', '2016-01-07', '2016-01-06', '2016-01-05',
#                '2016-01-04', '2015-12-31'],
#               dtype='datetime64[ns]', name='Date', length=504, freq=None)

# %%
p.major_xs
# Out:
# <bound method Panel.major_xs of <class 'pandas.core.panel.Panel'>
# Dimensions: 6 (items) x 504 (major_axis) x 5 (minor_axis)
# Items axis: Adj Close to Volume
# Major_axis axis: 2017-12-29 00:00:00 to 2015-12-31 00:00:00
# Minor_axis axis: AMZN to FB>

# %%
p.ndim
# Out:
# 3

# %%
p.dtypes
# Out:
# Adj Close    float64
# Close        float64
# High         float64
# Low          float64
# Open         float64
# Volume       float64
# dtype: object

# %%
p.shape
# Out:
# (6, 504, 5)

# %%
p.size  # to get .size result multiply .shape values by each
# Out:
# 15120

# %% [markdown]
# ### Pulling out data from specific columns  .loc[ ]   .iloc[ ],   .ix[ ]

# %%
p.Open.head()
# Out:
#                    AMZN         CAT         CVX         DB          FB
# Date
# 2017-12-29  1182.349976  158.050003  125.360001  19.070000  178.000000
# 2017-12-28  1189.000000  157.940002  125.690002  19.139999  177.949997
# 2017-12-27  1179.910034  156.940002  125.959999  19.260000  176.550003
# 2017-12-26  1168.359985  156.039993  125.230003  19.370001  176.630005
# 2017-12-22  1172.079956  154.770004  124.849998  19.450001  177.139999

# %%
p.loc['Close','2016-11-15','DB']
# Out:
# Date
# 2016-11-15    16.549999
# Name: DB, dtype: float64

# %%
p.items
# Out:
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
p.iloc[4,34]   # [ column, row ]
# Out:
# AMZN    1125.959961
# CAT      136.440002
# CVX      115.900002
# DB        17.280001
# FB       178.309998
# Name: 2017-11-09 00:00:00, dtype: float64

# %%
p.ix['High',11]
# Out:
# AMZN    1170.869995
# CAT      149.050003
# CVX      120.169998
# DB        19.480000
# FB       179.160004
# Name: 2017-12-13 00:00:00, dtype: float64

# %% [markdown]
# ### Convert to a Multiindex DataFrame

# %%
p.to_frame()
# Out:
#                     Adj Close        Close         High          Low  \
# Date       minor
# 2017-12-29 AMZN   1169.469971  1169.469971  1184.000000  1167.500000
#            CAT     156.851974   157.580002   158.500000   157.509995
#            CVX     123.956055   125.190002   125.980003   125.190002
#            DB       19.030001    19.030001    19.100000    18.990000
#            FB      176.460007   176.460007   178.850006   176.460007
# 2017-12-28 AMZN   1186.099976  1186.099976  1190.099976  1184.380005
#            CAT     157.688095   158.419998   158.649994   157.229996
#            CVX     124.342209   125.580002   125.889999   125.290001
#            DB       19.100000    19.100000    19.170000    19.010000
#            FB      177.919998   177.919998   178.940002   177.679993
# 2017-12-27 AMZN   1182.260010  1182.260010  1187.290039  1175.609985
#            CAT     156.792267   157.520004   157.690002   156.309998
# ...

# %%
p.major_xs('2016-10-14')
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 6 (items) x 1 (major_axis) x 5 (minor_axis)
# Items axis: Adj Close to Volume
# Major_axis axis: 2016-10-14 00:00:00 to 2016-10-14 00:00:00
# Minor_axis axis: AMZN to FB

# %%
p.minor_xs('FB').tail()
# Out:
#              Adj Close       Close        High         Low        Open  \
# Date
# 2016-01-07   97.919998   97.919998  101.430000   97.300003  100.500000
# 2016-01-06  102.970001  102.970001  103.769997  100.900002  101.129997
# 2016-01-05  102.730003  102.730003  103.709999  101.669998  102.889999
# 2016-01-04  102.220001  102.220001  102.239998   99.750000  101.949997
# 2015-12-31  104.660004  104.660004  106.169998  104.620003  106.000000
#
#                 Volume
# Date
# 2016-01-07  45172900.0
# 2016-01-06  25096200.0
# 2016-01-05  23258200.0
# 2016-01-04  37912400.0
# 2015-12-31  18391100.0

# %%
p
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 6 (items) x 504 (major_axis) x 5 (minor_axis)
# Items axis: Adj Close to Volume
# Major_axis axis: 2017-12-29 00:00:00 to 2015-12-31 00:00:00
# Minor_axis axis: AMZN to FB

# %%
p2.axes
# Out:
# [Index(['AMZN', 'CAT', 'CVX', 'DB', 'FB'], dtype='object'),
#  DatetimeIndex(['2017-12-29', '2017-12-28', '2017-12-27', '2017-12-26',
#                 '2017-12-22', '2017-12-21', '2017-12-20', '2017-12-19',
#                 '2017-12-18', '2017-12-15',
#                 ...
#                 '2016-01-14', '2016-01-13', '2016-01-12', '2016-01-11',
#                 '2016-01-08', '2016-01-07', '2016-01-06', '2016-01-05',
#                 '2016-01-04', '2015-12-31'],
#                dtype='datetime64[ns]', name='Date', length=504, freq=None),
#  Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')]
